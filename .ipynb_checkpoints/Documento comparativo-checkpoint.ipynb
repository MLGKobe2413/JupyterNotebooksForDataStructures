# %% [raw]
# Comparación entre implementación de Linear Probing (LP) y de
# Separate Chaining (SC) para carga de datos de tipo <Integer, Integer>
#
# Se usan diferentes factores de carga:
# Para LP, los factores son 0.25, 0.5, 0.75
#
# Para SC, los factores son 3, 5, 7
#
# Por: Pietro Ehrlich y Jorge Esguerra

# %%
import numpy as np
factoresCargaLP = [0.25,0.5,0.75]
factoresCargaSC = [3,5,7]

# %%
# Ahora, se añadirán los tiempos tardados por ambas implementaciones en las operaciones de put y get.
# Se grafica un promedio de 10 corridas de cada uno de los métodos, de acuerdo con las clases SeparateChainingTest 
# Y LinearProbingTest, presentes en el repositorio.

# Datos
timesLPput025 = [281,252,255,244,236,295,522,286,265,259]
timesLPget025 = [7,7,7,7,7,7,7,7,8,7]
timesLPput05 = [236, 225,269,278,276,299,168,184,215,233]
timesLPget05 = [7,7,7,7,6,7,6,6,7,7]
timesLPput075 = [326, 204,275,199,274,255,201,179,206,285]
timesLPget075 = [7,7,7,7,7,7,6,5,6,6]

timesSCput3 = [319, 363, 346,350,349,333,349,342,379,380]
timesSCget3 = [12,13,14,14,14,14,14,16,15,16]
timesSCput5 = [392, 393, 358,367,392,361,295,363,383,309]
timesSCget5 = [7,8,8,8,8,8,7,9,7,8]
timesSCput7 = [428, 397, 455,434,407,386,271,312,479,389]
timesSCget7 = [7,7,8,10,8,8,7,8,7,8]

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# Sacamos los promedios de esas 10 corridas de los datos
avgLPput025 = np.mean(timesLPput025)

avgLPput05 = np.mean(timesLPput05)

avgLPput075 = np.mean(timesLPput075)

avgLPget025 = np.mean(timesLPget025)

avgLPget05 = np.mean(timesLPget05)

avgLPget075 = np.mean(timesLPget075)

avgSCput3 = np.mean(timesSCput3)

avgSCput5 = np.mean(timesSCput5)

avgSCput7 = np.mean(timesSCput7)

avgSCget3 = np.mean(timesSCget3)

avgSCget5 = np.mean(timesSCget5)

avgSCget7 = np.mean(timesSCget5)


LPput = [avgLPput025, avgLPput05, avgLPput075]

# %%
fig, ax = plt.subplots()
index = np.arange(3)
bar_width = 0.05

opacity = 0.4

rects1 = ax.bar(factoresCargaLP[0], LPput[0], bar_width, alpha = opacity, color = 'b', label = 'LP 0.25')
rects2 = ax.bar(factoresCargaLP[1], LPput[1], bar_width, alpha = opacity, color = 'r', label = 'LP 0.5')
rects3 = ax.bar(factoresCargaLP[2], LPput[2], bar_width, alpha = opacity, color = 'g', label = 'LP 0.75')


ax.set_xlabel('Factores de Carga')
ax.set_ylabel('Tiempo promedio en milisegundos')
ax.set_title('LP put')



ax.legend(loc='best')
fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
index = np.arange(3)
bar_width = 0.2

opacity = 0.4

rects4 = ax.bar(factoresCargaSC[0], avgSCput3, bar_width, alpha = opacity, color = 'purple', label = 'SC 3')
rects5 = ax.bar(factoresCargaSC[1], avgSCput5, bar_width, alpha = opacity, color = 'gold', label = 'SC 5')
rects6 = ax.bar(factoresCargaSC[2], avgSCput7, bar_width, alpha = opacity, color = 'green', label = 'SC 7')
rects7 = ax.bar(factoresCargaSC[2]+2, 0, bar_width, alpha = opacity)


ax.set_xlabel('Factores de Carga')
ax.set_ylabel('Tiempo promedio en milisegundos')
ax.set_title('SC put')



ax.legend(loc='best')
fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
index = np.arange(3)
bar_width = 0.05

opacity = 0.4

rects1 = ax.bar(factoresCargaLP[0], avgLPget025, bar_width, alpha = opacity, color = 'b', label = 'LP 0.25')
rects2 = ax.bar(factoresCargaLP[1], avgLPget05, bar_width, alpha = opacity, color = 'r', label = 'LP 0.5')
rects3 = ax.bar(factoresCargaLP[2], avgLPget075, bar_width, alpha = opacity, color = 'g', label = 'LP 0.75')
rects6 = ax.bar(1, 0, bar_width, alpha = opacity)

ax.set_xlabel('Factores de Carga')
ax.set_ylabel('Tiempo promedio en milisegundos')
ax.set_title('LP get')



ax.legend(loc='best')
fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
index = np.arange(3)
bar_width = 0.2

opacity = 0.4

rects1 = ax.bar(factoresCargaSC[0], avgSCget3, bar_width, alpha = opacity, color = 'b', label = 'SC 3')
rects2 = ax.bar(factoresCargaSC[1], avgSCget5, bar_width, alpha = opacity, color = 'r', label = 'SC 5')
rects3 = ax.bar(factoresCargaSC[2], avgSCget5, bar_width, alpha = opacity, color = 'g', label = 'SC 7')


ax.set_xlabel('Factores de Carga')
ax.set_ylabel('Tiempo promedio en milisegundos')
ax.set_title('SC get')



ax.legend(loc='best')
fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Conclusiones:
#
# La implementación de SC fue más efectiva para las consultas a partir de factores de carga de 5, para el factor de carga 3, fue casi el doble de lenta que para 5 y 7.
#
# La implementación de SC siempre tardó más que la de LP en cargar los datos, por el hecho de manejo y creación de linkedlists.
#
# En estos tests es imposible ver las ventajas que trae consigo la implementación SC, dado que no se generó un caso de prueba en el que la búsqueda se volviera O(n) para LP.
#
# El desempeño de las consultas en LP fue bastante consistente, como lo evidencia la gráfica LP Get.
#
# Mientras que la carga en LP fue más rápida en los factores de carga más altos, en SC la carga fue más rápida en factores de carga más bajos.
